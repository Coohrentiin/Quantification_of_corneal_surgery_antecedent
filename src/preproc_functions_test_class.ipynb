# %%
from image_OCT_2 import * 
import os
from image_Quantification_3 import *
# pathname = 'C:\\Users\\Maëlle\\Documents\\Rédaction\\_Article in vivo\\code' # chemin du dossier où est stockée l'image
dirname = os.getcwd()
# pathname=os.path.join(dirname,"..", 'Data','VILBERT_Maelle')
# filename = '_VILBERT_Maëlle__98276_Cornea Line_OD_2021-06-28_17-50-39_F_1994-02-07_1_sans-lumière-rouge-macro.jpg' # nom de l'image
pathname=os.path.join(dirname,"..", 'Data','HAZE')
filename = 'haze 1.jpg' # nom de l'image

im = image_OCT(pathname, filename)
im.AutoTreatment()

# %%
plt.imshow(im.OCT_flat,cmap="gray")

# %%
# from os import listdir
# from os.path import isfile, join
# from image_Quantification_3 import *

# repository=os.path.join(dirname,"..", 'Data','Healthy')

# files = [f for f in listdir(repository) if isfile(join(repository, f))]
# quantification=[]
# i=0
# i_list=[]
# for f in files:
# 	if(f[-3:]=="jpg"):
# 		i+=1
# 		# try:
# 		# im=image_OCT(os.path.join(repository, f))
# 		im=image_OCT(repository, f)
# 		im.AutoTreatment()
# 		# print(im.OCT_flat.shape[1])
# 		# plt.imshow(im.OCT_flat)
# 		# plt.show()
# 		im_Q=image_Quantification_3(im,movingWin=True,eliminate=30,useExpCorr=False)
# 		plt.imshow(im_Q.image_init)
# 		plt.show()
# 		# except:
# 		# 	print("Oups")

# %%
repertory_haze=os.path.join(dirname,'..', 'Data','HAZE')
healthy_value=0 #patho
data_haze=create_new_dataset(repertory_haze,healthy_value,movingWin=False,eliminate=30,useExpCorr=False)
# Out:
# 6 / 6  files succesfully quantified
